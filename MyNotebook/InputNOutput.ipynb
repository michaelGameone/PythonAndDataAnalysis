# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\michael\\LocalGitProject\\PythonAndDataAnalysis\\MyNotebook'

# %%
pd.read_csv('example') # read csv file as a dataframe
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
inputDf = pd.read_json("jsonDataFile")
inputDf
# Out:
#           Region      Country  Year Sales Platform  Sales
# 0  North America           US  2022         Amazon    500
# 1           Asia        Japan  2022     AliExpress   3200
# 2           Asia  South Korea  2023         Amazon    600
# 3  North America        Canda  2023           Temu   4230
# 4         Europe           UK  2022         Amazon   6100
# 5           Asia        Japan  2023     AliExpress    680
# 6         Europe      Germany  2022           Temu    100
# 7  North America           US  2023         Amazon   5800
# 8         Europe           UK  2023     AliExpress   5600

# %%
salesSummaryDF = inputDf.pivot_table(values="Sales",index=["Year"], aggfunc="sum")
salesSummaryDF
# Out:
#       Sales
# Year
# 2022   9900
# 2023  16910

# %%
salesSummaryDF.to_csv("outputSalesSummary")

# %%
pd.read_csv("outputSalesSummary")
# Out:
#    Year  Sales
# 0  2022   9900
# 1  2023  16910

# %%
temp = pd.read_csv("outputSalesSummary")
temp.to_csv("anotherSum")

# %%
pd.read_csv("anotherSum")
# Out:
#    Unnamed: 0  Year  Sales
# 0           0  2022   9900
# 1           1  2023  16910

# %%
temp.to_csv("anotherSum", index=False)
pd.read_csv("anotherSum")
# Out:
#    Year  Sales
# 0  2022   9900
# 1  2023  16910

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1') # it will contain "Unnamed: 0" column
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1', index_col=[0]) # now it eliminate the "Unnamed: 0" column
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
inputDf
# Out:
#           Region      Country  Year Sales Platform  Sales
# 0  North America           US  2022         Amazon    500
# 1           Asia        Japan  2022     AliExpress   3200
# 2           Asia  South Korea  2023         Amazon    600
# 3  North America        Canda  2023           Temu   4230
# 4         Europe           UK  2022         Amazon   6100
# 5           Asia        Japan  2023     AliExpress    680
# 6         Europe      Germany  2022           Temu    100
# 7  North America           US  2023         Amazon   5800
# 8         Europe           UK  2023     AliExpress   5600

# %%
salesByPlaformDF = inputDf.pivot_table(values="Sales", index=["Sales Platform", "Country"], aggfunc="sum")
salesByPlaformDF
# Out:
#                             Sales
# Sales Platform Country
# AliExpress     Japan         3880
#                UK            5600
# Amazon         South Korea    600
#                UK            6100
#                US            6300
# Temu           Canda         4230
#                Germany        100

# %%
# output to excel
salesByPlaformDF.to_excel("outputSalesByPlatform.xlsx",sheet_name="Platform Sales")

# %%
htmlDf = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")
htmlDf
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0                        Citizens Bank       Sac City      IA      8758
#  1             Heartland Tri-State Bank        Elkhart      KS     25851
#  2                  First Republic Bank  San Francisco      CA     59017
#  3                       Signature Bank       New York      NY     57053
#  4                  Silicon Valley Bank    Santa Clara      CA     24735
#  ..                                 ...            ...     ...       ...
#  563                 Superior Bank, FSB       Hinsdale      IL     32646
#  564                Malta National Bank          Malta      OH      6629
#  565    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  566  National State Bank of Metropolis     Metropolis      IL      3815
#  567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
type(htmlDf)
# Out:
# list

# %%
htmlDf[0]
# Out:
#                          Bank NameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
htmlDf[0].head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539
